# %%
arr.pop(i) # removes the ith element from the array. If no index is specified, pop() removes and returns the last item in the list.
arr.sort() # sorts the array in increasing order
9//2 # divides by 2 and then round down so equals 4
temp,nums[i+1]=nums[i+1],temp # swaps temp with nums[i+1] this does the swap simultaneously
29 % 8 # returns the remainder of dividing two numbers. This would equal 5
max(currentProfit,max_profit) # returns the max between the 2 (min also works the same)

arr.append(x) # Adds an item x to the end of the list.
arr.extend(iterable) # Extends the list by appending all the items from the iterable.
arr.insert(i, x) # Inserts an item at a given position.
arr.remove(x) # Removes the first item from the list whose value is x.
arr.replace('IX','VIII') # in the string arr replace every occurence of'IX' with 'VIII'
string.lower() # make a string all lowercase
string.upper() # make a string all upercase

# FOR LOOPS
for i in arr: # loops through each element of the array (i is each element) if arr is a string the loop iterates through each letter
for i in range(len(arr)) # loops through the index of the array starting at 0 and finishing at final index of array (i is index and arr[i] is the element) range(6) is not the values of 0 to 6, but the values 0 to 5.
for i in range(1,len(arr)): # starts at index=1 and ends at index of last element in array because if len=5 the last element is at index=4
for i in range(1,5): # starts at index=1 and ends at index=4
for i in range(2, 30, 3): # starts at index=2 ends at index=30 and increments in steps of 3

x = -i # this means that x starts at the end of the arr with -1 being the last element in the array (i must be index, not the element) so maybe do (x = -i-1) instead

# WHILE LOOP:
i = 1 # must initiate i before loop
while i < 6: # if i=6 the loop stops
  print(i)
  i+=1 # increases i by 1 for the next loop, must  have something to change i or else loop would be infinite


# IF STATEMENT
if arr[i]==val:
  something
elif arr[i]>val:
  something
else:
  somehing

if x == 3:
  break   # exits the loop at this point

# PASS
for i in arr:
  pass  # this does nothing just stops an empty loop from giving an error

# CONTINUE
for i in arr:
  if i==4:
    continue # the continue statement stops the current iteration of the loop, and continues with the next:
  print(i)

# RETURN
return result # exits the whole function and returns result

# %%
arr = ['hello','world']
for i in arr:
    for j in range(len(i)):
      x=-j-1
      print(i[j],i[x])
    print(i)
# Out:
# h o
# e l
# l l
# l e
# o h
# hello
# w d
# o l
# r r
# l o
# d w
# world

# %%
string = 'HellO'
print(string.lower())
# Out:
# hello
